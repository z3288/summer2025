# %% [markdown]
# # This file is to test the dataset and to also download any libraries
# ### File made by Brandon Swanson during SULI while at Argonne National Labratory

# %%
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import pandas as pd
from scipy.io import netcdf
import netCDF4 as nc

# %%
ds = xr.open_dataset('data/UIC_AQT/crocus-UIC-aqt-a1-20240722-000000.nc',engine='netcdf4')
ds
# Out:
# <xarray.Dataset> Size: 415kB
# Dimensions:      (time: 4320)
# Coordinates:
#   * time         (time) datetime64[ns] 35kB 2024-07-22T00:00:14.447356906 ......
# Data variables:
#     pm2.5        (time) float64 35kB ...
#     pm1.0        (time) float64 35kB ...
#     pm10.0       (time) float64 35kB ...
#     no           (time) float64 35kB ...
#     o3           (time) float64 35kB ...
#     no2          (time) float64 35kB ...
#     co           (time) float64 35kB ...
#     temperature  (time) float64 35kB ...
#     humidity     (time) float64 35kB ...
#     pressure     (time) float64 35kB ...
#     dewpoint     (time) float64 35kB ...
# Attributes:
#     conventions:  CF 1.10
#     WSN:          W096
#     site_ID:      UIC
#     CAMS_tag:     CMS-WXT-011
#     datastream:   crocus_uic_aqt_a1
#     plugin:       registry.sagecontinuum.org/jrobrien/waggle-aqt:0.23.5.04
#     datalevel:    a1
#     latitude:     41.869407936
#     longitude:    -87.645806251

# %%
ds["pm2.5"].plot()

# %%
ds["pm1.0"].plot()

# %%
ds["pm1.0"].plot()

# %%
ds["pm10.0"].plot()

# %%
ds["no"].plot()

# %%
ds["o3"].plot()

# %%
ds["no2"].plot()

# %%
ds["co"].plot()

# %%
ds["temperature"].plot()

# %%
ds["humidity"].plot()

# %%
ds["pressure"].plot()

# %%
ds["dewpoint"].plot()

# %%
x = ds["pm2.5"]

y = ds["time"]
# figure
fig,ax = plt.subplots(1,1, figsize=(8, 5))
ax.plot(y,x)
ax.set(xlabel = 'Date & Time', ylabel = 'Mole Concentration of pm2.5 (µg/m³)')
plt.title("pm2.5 Concentration over UIC")
plt.show()
